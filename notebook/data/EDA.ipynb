# %% [markdown]
# ### Import necessery library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Read Data

# %%
df=pd.read_csv(r'D:\Credit_Card\notebook\data\raw.csv')

# %%
# Top five values
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
# Dimesion of the data
df.shape
# Out:
# (30000, 25)

# %%
# Dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  float64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  float64
# ...

# %%
# data stats values
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
# Check null values
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %% [markdown]
#  We can observ there is no null values present in the datasets.

# %%
# let's check duplicate values
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
#  We can observ there is no duplicate values present in the datasets.

# %% [markdown]
# ### Let's Check unique values

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Distribution of LIMIT_BAL
plt.figure(figsize=(10, 6))
sns.histplot(df['LIMIT_BAL'], kde=True)
plt.title('Distribution of LIMIT_BAL')
plt.show()

# %%
# Distribution of AGE
plt.figure(figsize=(10, 6))
sns.histplot(df['AGE'], kde=True)
plt.title('Distribution of AGE')
plt.show()

# %%
# Distribution of PAY_0
plt.figure(figsize=(10, 6))
sns.countplot(x='PAY_0', data=df)
plt.title('Distribution of PAY_0')
plt.show()

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns
# plt.figure(figsize=(15, 30))

# for i, feature in enumerate(df.columns):
#     plt.subplot(10,3, i + 1)
#     sns.histplot(data=df[feature], bins=20, kde=True)
#     plt.title(feature)
# plt.tight_layout()
# plt.show()

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default.payment.next.month'],
#       dtype='object')

# %%
# Distribution of PAY_2
plt.figure(figsize=(10, 5))
sns.countplot(x='PAY_2', data=df)
plt.title('Distribution of PAY_2')
plt.show()

# %%
# Distribution of PAY_3
plt.figure(figsize=(10, 5))
sns.countplot(x='PAY_3', data=df)
plt.title('Distribution of PAY_3')
plt.show()

# %%
# Distribution of PAY_3
plt.figure(figsize=(10, 5))
sns.countplot(x='PAY_3', data=df)
plt.title('Distribution of PAY_3')
plt.show()

# %%
# Distribution of default.payment.next.month
plt.figure(figsize=(10, 5))
sns.countplot(x='default.payment.next.month', data=df)
plt.title('Distribution of default payment next month')
plt.show()

# %%
df['default.payment.next.month'].value_counts()
# Out:
# default.payment.next.month
# 0    23364
# 1     6636
# Name: count, dtype: int64

# %% [markdown]
# We can see that our data is imbalanced

# %%
from sklearn.utils import resample
# create data frame minority and majority class
majority = df[(df['default.payment.next.month']==0)]
minority = df[(df['default.payment.next.month']==1)]

minority_upsample = resample(minority,
                           replace=True,
                            n_samples=23364,
                            random_state=0)

# combine majority class and unsample minority class
df = pd.concat([minority_upsample, majority])

# %%
# Distribution of default.payment.next.month
plt.figure(figsize=(10, 5))
sns.countplot(x='default.payment.next.month', data=df)
plt.title('Distribution of default payment next month')
plt.show()

# %% [markdown]
# We can see that our data is balanced

# %%
# Correlation matrix
corr_matrix = df.corr()

# Heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Boxplot for LIMIT_BAL
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['LIMIT_BAL'])
plt.title('Boxplot of LIMIT_BAL')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15, 30))

for i, feature in enumerate(df.columns):
    plt.subplot(10,3, i + 1)
    sns.boxplot(data=df[feature], bins=20, kde=True)
    plt.title(feature)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 7
#       5 for i, feature in enumerate(df.columns):
#       6     plt.subplot(10,3, i + 1)
# ----> 7     sns.boxplot(data=df[feature], bins=20, kde=True)
#       8     plt.title(feature)
#       9 plt.tight_layout()
#
# File d:\Credit_Card\venv\lib\site-packages\seaborn\categorical.py:1634, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1627 color = _default_color(
#    1628     ax.fill_between, hue, color,
#    1629     {k: v for k, v in kwargs.items() if k in ["c", "color", "fc", "facecolor"]},
#    1630     saturation=saturation,
#    1631 )
#    1632 linecolor = p._complement_color(linecolor, color, p._hue_map)
# -> 1634 p.plot_boxes(
# ...

# %% [markdown]
# ### Outlier Detection

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Adjust the figure size
plt.figure(figsize=(15, 30))

# Enumerate through each feature column in the DataFrame
for i, feature in enumerate(df.columns):
    plt.subplot(10, 3, i + 1)
    if df[feature].dtype == 'object':
        sns.boxplot(x=df[feature])
    else:
        sns.boxplot(x=df[feature])
    plt.title(feature)

plt.tight_layout()
plt.show()

# %% [markdown]
# We can see that our maximum columns have outlier

# %%
# Impute outliers with median
def impute_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    median = df[column].median()
    df[column] = np.where((df[column] < lower_bound) | (df[column] > upper_bound), median, df[column])
    return df

for col in df.select_dtypes(include=['float64', 'int64']).columns:
    df = impute_outliers(df, col)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Adjust the figure size
plt.figure(figsize=(15, 30))

# Enumerate through each feature column in the DataFrame
for i, feature in enumerate(df.columns):
    plt.subplot(10, 3, i + 1)
    if df[feature].dtype == 'object':
        sns.boxplot(x=df[feature])
    else:
        sns.boxplot(x=df[feature])
    plt.title(feature)

plt.tight_layout()
plt.show()
